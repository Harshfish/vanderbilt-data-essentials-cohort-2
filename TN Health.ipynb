# %%
import pandas as pd

# %%
! dir
# Out:
#  Volume in drive C is Win
#  Volume Serial Number is EC9E-53D7
#
#  Directory of C:\Users\ivano\Documents\Projects
#
# 09/04/2019  10:15 AM    <DIR>          .
# 09/04/2019  10:15 AM    <DIR>          ..
# 09/04/2019  10:15 AM               713  Week1.ipynb
# 09/04/2019  10:10 AM    <DIR>          .ipynb_checkpoints
# 09/04/2019  09:53 AM    <DIR>          class_notebooks
# 09/04/2019  09:53 AM    <DIR>          data
# 09/04/2019  09:53 AM    <DIR>          slides
# 09/04/2019  10:09 AM                72 Untitled.ipynb
# 09/04/2019  09:57 AM    <DIR>          vanderbilt-data-essentials-cohort-2
#                2 File(s)            785 bytes
#                7 Dir(s)  28,531,904,512 bytes free

# %%
HA = pd.read_csv('vanderbilt-data-essentials-cohort-2/data/mmd_heart_attack_data.csv')

# %%
HA.head()
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                    condition primary_sex  \
# 0  Primary chronic conditions  Acute myocardial infarction         All
# 1  Primary chronic conditions  Acute myocardial infarction         All
# 2  Primary chronic conditions  Acute myocardial infarction         All
# 3  Primary chronic conditions  Acute myocardial infarction         All
# 4  Primary chronic conditions  Acute myocardial infarction         All
#
#   primary_age     primary_dual  fips          county    state  urban  \
# ...

# %%
HA.info
# Out:
# <bound method DataFrame.info of       year geography             measure         adjustment      analysis  \
# 0     2017    County  Average total cost  Unsmoothed actual  Base measure
# 1     2017    County  Average total cost  Unsmoothed actual  Base measure
# 2     2017    County  Average total cost  Unsmoothed actual  Base measure
# 3     2017    County  Average total cost  Unsmoothed actual  Base measure
# 4     2017    County  Average total cost  Unsmoothed actual  Base measure
# 5     2017    County  Average total cost  Unsmoothed actual  Base measure
# 6     2017    County  Average total cost  Unsmoothed actual  Base measure
# 7     2017    County  Average total cost  Unsmoothed actual  Base measure
# 8     2017    County  Average total cost  Unsmoothed actual  Base measure
# 9     2017    County  Average total cost  Unsmoothed actual  Base measure
# 10    2017    County  Average total cost  Unsmoothed actual  Base measure
# ...

# %%
HA.columns
# Out:
# Index(['year', 'geography', 'measure', 'adjustment', 'analysis', 'domain',
#        'condition', 'primary_sex', 'primary_age', 'primary_dual', 'fips',
#        'county', 'state', 'urban', 'primary_race', 'primary_denominator',
#        'analysis_value'],
#       dtype='object')

# %%
HATN = HA.loc[HA.state == "TENNESSEE"]

# %%
HATN.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 2030 to 2120
# Data columns (total 17 columns):
# year                   91 non-null int64
# geography              91 non-null object
# measure                91 non-null object
# adjustment             91 non-null object
# analysis               91 non-null object
# domain                 91 non-null object
# condition              91 non-null object
# primary_sex            91 non-null object
# primary_age            91 non-null object
# primary_dual           91 non-null object
# fips                   91 non-null int64
# county                 91 non-null object
# state                  91 non-null object
# urban                  91 non-null object
# primary_race           91 non-null object
# primary_denominator    91 non-null object
# analysis_value         91 non-null int64
# dtypes: int64(3), object(14)
# memory usage: 12.8+ KB

# %%
HATN.tail()
# Out:
#       year geography             measure         adjustment      analysis  \
# 2116  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2117  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2118  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2119  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2120  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# 2116  Primary chronic conditions  Acute myocardial infarction         All
# 2117  Primary chronic conditions  Acute myocardial infarction         All
# 2118  Primary chronic conditions  Acute myocardial infarction         All
# 2119  Primary chronic conditions  Acute myocardial infarction         All
# 2120  Primary chronic conditions  Acute myocardial infarction         All
#
# ...

# %%
HATN.county.unique ()
# Out:
# array(['Anderson County', 'Bedford County', 'Benton County',
#        'Bledsoe County', 'Blount County', 'Bradley County',
#        'Campbell County', 'Cannon County', 'Carroll County',
#        'Carter County', 'Cheatham County', 'Chester County',
#        'Claiborne County', 'Clay County', 'Cocke County', 'Coffee County',
#        'Crockett County', 'Cumberland County', 'Davidson County',
#        'Decatur County', 'DeKalb County', 'Dickson County', 'Dyer County',
#        'Fayette County', 'Fentress County', 'Franklin County',
#        'Gibson County', 'Giles County', 'Grainger County',
#        'Greene County', 'Grundy County', 'Hamblen County',
#        'Hamilton County', 'Hardeman County', 'Hardin County',
#        'Hawkins County', 'Haywood County', 'Henderson County',
#        'Henry County', 'Hickman County', 'Houston County',
#        'Humphreys County', 'Jackson County', 'Jefferson County',
#        'Johnson County', 'Knox County', 'Lake County',
# ...

# %%
HATN.urban.value_counts()
# Out:
# Rural    53
# Urban    38
# Name: urban, dtype: int64

# %%
HATN.analysis_value.describe()
# Out:
# count       91.000000
# mean     45762.989011
# std       6574.670462
# min      30831.000000
# 25%      41105.500000
# 50%      45384.000000
# 75%      49698.500000
# max      62641.000000
# Name: analysis_value, dtype: float64

# %%
print('Costs for urban counties:')
print(HATN.loc[HATN.urban == 'Urban'].analysis_value.describe())
print('====================================')
print('Costs for rural counties:')
print(HATN.loc[HATN.urban == 'Rural'].analysis_value.describe())
# Out:
# Costs for urban counties:
# count       38.000000
# mean     45748.921053
# std       7109.788921
# min      32279.000000
# 25%      40452.750000
# 50%      45496.500000
# 75%      50734.500000
# max      61541.000000
# Name: analysis_value, dtype: float64
# ...
# Costs for rural counties:
# count       53.000000
# mean     45773.075472
# std       6232.724885
# min      30831.000000
# 25%      41240.000000
# 50%      45384.000000
# 75%      48998.000000
# max      62641.000000
# Name: analysis_value, dtype: float64

# %%
CA = pd.read_csv('vanderbilt-data-essentials-cohort-2/data/mmd_cancer_data.csv')

# %%
CA.head()
# Out:
#    year geography             measure         adjustment      analysis  \
# 0  2017    County  Average total cost  Unsmoothed actual  Base measure
# 1  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3  2017    County  Average total cost  Unsmoothed actual  Base measure
# 4  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                        domain                                   condition  \
# 0  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 1  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 4  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#   primary_sex primary_age     primary_dual  fips          county    state  \
# ...

# %%
CA.shape
# Out:
# (3165, 17)

# %%
CA.state.unique()
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DELAWARE', 'DISTRICT OF COLUMBIA',
#        'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA',
#        'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND',
#        'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI',
#        'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE',
#        'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA',
#        'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA',
#        'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA', 'WASHINGTON',
#        'WEST VIRGINIA', 'WISCONSIN', 'WYOMING', 'PUERTO RICO'],
#       dtype=object)

# %%
CA = CA.loc[CA.state == 'TENNESSEE']
CA.shape
# Out:
# (95, 17)

# %%
import pandas as pd

# %%
income_dict = pd.read_csv("vanderbilt-data-essentials-cohort-2/data/irs_county_2016.csv")

# %%
income_dict.head()
# Out:
#    STATEFIPS STATE  COUNTYFIPS COUNTYNAME  agi_stub      N1   mars1   MARS2  \
# 0          1    AL           0    Alabama         1   26450   14680    9740
# 1          1    AL           0    Alabama         2  285760  217880   25170
# 2          1    AL           0    Alabama         3  529780  259680   80320
# 3          1    AL           0    Alabama         4  495750  211100  141800
# 4          1    AL           0    Alabama         5  263130   82330  137610
#
#     MARS4    PREP  ...  N10300   A10300  N85530  A85530  N85300  A85300  \
# 0     680   17780  ...    4300     9256      70      57       0       0
# 1   39740  143390  ...   70050    40569       0       0       0       0
# 2  181410  297440  ...  297770   290358       0       0       0       0
# 3  127420  272030  ...  397940   983800      40      22       0       0
# 4   35760  154540  ...  252940  1346083      20      27       0       0
#
#    N11901  A11901  N11902   A11902
# 0    2590    3685   11510    35079
# ...

# %%
income_dict.shape
# Out:
# (25536, 148)

# %%
income_dict.STATE.unique()
# Out:
# array(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA',
#        'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA',
#        'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY',
#        'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'], dtype=object)

# %%
TN_income = income_dict.loc[income_dict.STATE == 'TN']

# %%
TN_income.head()
# Out:
#       STATE COUNTYNAME  agi_stub      N1   mars1   MARS2   MARS4       N2  \
# 19752    TN  Tennessee         1   39580   22400   14440     980    60360
# 19753    TN  Tennessee         2  439770  345410   39920   49300   443540
# 19754    TN  Tennessee         3  717430  398720  115040  189290  1269420
# 19755    TN  Tennessee         4  759340  355970  217710  159890  1486710
# 19756    TN  Tennessee         5  396810  128390  215890   42240   881020
#
#        NUMDEP  ELDERLY    A00100  N02650    A02650  N02300  A02300
# 19752    8230    19090  -2747555   29090  -2710342      90     348
# 19753  108380    74190   2366417  439780   2441687    4830   12132
# 19754  472350   141070  12289681  717430  12486175   19660   58771
# 19755  512170   154020  27370414  759340  27694026   19120   57012
# 19756  268500   106740  24350682  396810  24651803   10630   33894

# %%
TN_income.tail()
# Out:
#       STATE     COUNTYNAME  agi_stub     N1  mars1  MARS2  MARS4     N2  \
# 20515    TN  Wilson County         4  14400   7130   4050   2610  27040
# 20516    TN  Wilson County         5   9330   2890   5160    960  21000
# 20517    TN  Wilson County         6   7160   1060   5630    380  18780
# 20518    TN  Wilson County         7  10350    780   9260    240  29640
# 20519    TN  Wilson County         8   2370    180   2130     50   6720
#
#        NUMDEP  ELDERLY   A00100  N02650   A02650  N02300  A02300
# 20515    8660     3140   526285   14400   534076     260     816
# 20516    6520     2440   577200    9330   585294     160     530
# 20517    6000     1910   621704    7160   629408     130     485
# 20518   10040     2600  1384798   10350  1404054     170     600
# 20519    2220      700   948065    2370   968457      30     118

# %%
TN_income.shape
# Out:
# (768, 15)

# %%
TN_income_select = TN_income[['Total','Under $1','Between 1 and $10,000','Between 10,000 and $25,000','Between 25,000 and $50,000','Between 50,000 and $75,000','Between 75,000 and $100,000','Between 100,000 and $200,000','$200,000 or more']]
income_select.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-1497fe262fde> in <module>
# ----> 1 TN_income_select = TN_income[['Total','Under $1','Between 1 and $10,000','Between 10,000 and $25,000','Between 25,000 and $50,000','Between 50,000 and $75,000','Between 75,000 and $100,000','Between 100,000 and $200,000','$200,000 or more']]
#       2 income_select.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
# ...
